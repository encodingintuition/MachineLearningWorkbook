# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Content
#
# - []()

# %%
# data DICT
|---|---|
|:---:|:
# Out:
#   File "<ipython-input-265-12fc97eef966>", line 2
#     |---|---|
#     ^
# SyntaxError: invalid syntax

# %%
# read Survey 

df1 = pd.read_excel('../data/Post-pandemic_travel_lodging-1.xlsx', head = None )
print(df1.shape)
df1.head(1)
# Out:
# (32, 23)
#                 Timestamp  What is your age?  What is your home zip code?  \
# 0 2021-03-23 15:38:11.493               34.0                      10514.0
#
#   When you hear the term "bed and breakfast", what comes to mind?  \
# 0                                 Charming vacation
#
#    How often do you usually travel?  \
# 0                                 2
#
#   What type of lodging do you most often stay at when you travel?   \
# 0                                              Hotel
#
#   Why do you typically choose that lodging option?  \
# 0                  Experience. Know what to expect
#
#   Who do you usually travel with? How many people do you travel with?  \
# 0                     With family                          3-4 people
#
#    How do you typically find places to stay at while traveling? Please rank from 1-4, with 4 being the method you rely on most. [Recommendations from friends/family]  \
# 0                                                  1
#
#    ...  \
# 0  ...
#
#    Do you prefer to use an app or website when booking your travel accommodations?  \
# 0                                            Website
#
#    When you book a vacation, what matters to you? Please rank from 1-6, with 6 being most important. [Tours and excursions]  \
# 0                                                  6
#
#    When you book a vacation, what matters to you? Please rank from 1-6, with 6 being most important. [Food/Restaurants/Bars]  \
# 0                                                  4
#
#   When you book a vacation, what matters to you? Please rank from 1-6, with 6 being most important. [Relaxation]  \
# 0                                                  3
#
#    When you book a vacation, what matters to you? Please rank from 1-6, with 6 being most important. [Shopping]  \
# 0                                                  1
#
#    When you book a vacation, what matters to you? Please rank from 1-6, with 6 being most important. [Meeting new people]  \
# 0                                                  2
#
#    When you book a vacation, what matters to you? Please rank from 1-6, with 6 being most important. [Immersing yourself in a new place]  \
# 0                                                  5
#
#    Have you travelled during the pandemic?  \
# 0                                      Yes
#
#    If you travelled during the pandemic, what type of lodging did you stay at and why?  \
# 0                                Hotel for ease/safe
#
#    If you travelled during the pandemic, did you have any concerns or difficulties during your stay in relation to COVID? If so, what were they?
# 0                                                 No
#
# [1 rows x 23 columns]

# %%
# Rename columns 

df1.columns = ['timestamp', 'age', 'zipcode', 'term_bnb', 'trav_per_year',
               'type_lodging', 'why_lodging', 'who_travel', 'num_people', 
              'find_rec', 'find_social', 'find_google', 'find_online', 
              'app_website', 'matters_tours', 'matters_food', 'matters_relax',
               'matters_shopping', 'matters_meeting' , 'matters_immersing',
              'covid_travel', 'covid_lodging', 'covid_issues']

# %%
# Reset index 

df1.reset_index(inplace = True)

# %%
df1.T
# Out:
#                                                 0   \
# index                                            0
# timestamp               2021-03-23 15:38:11.493000
# age                                             34
# zipcode                                      10514
# term_bnb                        Charming vacation
# trav_per_year                                    2
# type_lodging                                 Hotel
# why_lodging        Experience. Know what to expect
# who_travel                             With family
# num_people                              3-4 people
# find_rec                                         1
# find_social                                      2
# find_google                                      3
# find_online                                      4
# app_website                                Website
# matters_tours                                    6
# matters_food                                     4
# matters_relax                                    3
# matters_shopping                                 1
# matters_meeting                                  2
# matters_immersing                                5
# covid_travel                                   Yes
# covid_lodging                  Hotel for ease/safe
# covid_issues                                    No
#
#                                                   1   \
# index                                              1
# timestamp                 2021-03-23 15:40:28.494000
# age                                               53
# zipcode                                        60611
# term_bnb                               Tea and bread
# trav_per_year                                      1
# type_lodging                                   Hotel
# why_lodging        Free parking, breakfast included
# who_travel                               With family
# num_people                                1-2 people
# find_rec                                           2
# find_social                                        1
# find_google                                        4
# find_online                                        4
# app_website                                  Website
# matters_tours                                      1
# matters_food                                       3
# matters_relax                                      4
# matters_shopping                                   1
# matters_meeting                                    2
# matters_immersing                                  4
# covid_travel                                      No
# covid_lodging                                    NaN
# covid_issues                                     NaN
#
#                                                                   2   \
# index                                                              2
# timestamp                                 2021-03-23 15:41:27.211000
# age                                                               30
# zipcode                                                        60605
# term_bnb                  Motel, AirBnb, cozy lodging in countryside
# trav_per_year                                                      2
# type_lodging                                                   Hotel
# why_lodging        Easiest option to book without research, can u...
# who_travel                                               With family
# num_people                                                1-2 people
# find_rec                                                           3
# find_social                                                        4
# find_google                                                        2
# find_online                                                        1
# app_website                                                  Website
# matters_tours                                                      3
# matters_food                                                       4
# matters_relax                                                      2
# matters_shopping                                                   5
# matters_meeting                                                    6
# matters_immersing                                                  1
# covid_travel                                                      No
# covid_lodging                                                    NaN
# covid_issues                                                     NaN
#
#                                                                   3   \
# index                                                              3
# timestamp                                 2021-03-23 15:41:52.435000
# age                                                               58
# zipcode                                                        60611
# term_bnb           inexpensive lodging, comfort of home away from...
# trav_per_year                                                      1
# type_lodging                                                   Hotel
# why_lodging        location, proximity to places of interest, ame...
# who_travel           By myself, With friends, With family, With kids
# num_people                                                3-4 people
# find_rec                                                           2
# find_social                                                        2
# find_google                                                        4
# find_online                                                        1
# app_website                                                  Website
# matters_tours                                                      6
# matters_food                                                       4
# matters_relax                                                      4
# matters_shopping                                                   3
# matters_meeting                                                    2
# matters_immersing                                                  5
# covid_travel                                                      No
# covid_lodging                                                    NaN
# covid_issues                                                     NaN
#
#                                            4   \
# index                                       4
# timestamp          2021-03-23 15:42:36.842000
# age                                        23
# zipcode                                  1605
# term_bnb                                Homey
# trav_per_year                               1
# type_lodging                            Hotel
# why_lodging                      Convenience
# who_travel                        With family
# num_people                         1-2 people
# find_rec                                    2
# find_social                                 3
# find_google                                 4
# find_online                                 4
# app_website                           Website
# matters_tours                               1
# matters_food                                6
# matters_relax                               6
# matters_shopping                            5
# matters_meeting                             1
# matters_immersing                           5
# covid_travel                               No
# covid_lodging                             NaN
# covid_issues                              NaN
#
#                                                                   5   \
# index                                                              5
# timestamp                                 2021-03-23 15:43:05.047000
# age                                                               36
# zipcode                                                        20024
# term_bnb                                     Quaint vacation lodging
# trav_per_year                                                      2
# type_lodging                                                   Hotel
# why_lodging                              Consistent quality/features
# who_travel                                              with partner
# num_people                                                1-2 people
# find_rec                                                           2
# find_social                                                        1
# find_google                                                        3
# find_online                                                        4
# app_website                                                  Website
# matters_tours                                                      6
# matters_food                                                       3
# matters_relax                                                      4
# matters_shopping                                                   2
# matters_meeting                                                    1
# matters_immersing                                                  5
# covid_travel                                                     Yes
# covid_lodging      Hotel.  Normally would've stayed with family, ...
# covid_issues       Yes, staffing levels were reduced, which resul...
#
#                                                                   6   \
# index                                                              6
# timestamp                                 2021-03-23 15:43:18.448000
# age                                                               33
# zipcode                                                        60605
# term_bnb                            Small family-owned vacation home
# trav_per_year                                                      3
# type_lodging                                                   Hotel
# why_lodging        Big hotel chains are easy to find and expense ...
# who_travel                                                 By myself
# num_people                                                      None
# find_rec                                                           2
# find_social                                                        1
# find_google                                                        4
# find_online                                                        3
# app_website                                                  Website
# matters_tours                                                      6
# matters_food                                                       4
# matters_relax                                                      5
# matters_shopping                                                   2
# matters_meeting                                                    1
# matters_immersing                                                  3
# covid_travel                                                      No
# covid_lodging                                                    NaN
# covid_issues                                                     NaN
#
#                                                             7   \
# index                                                        7
# timestamp                           2021-03-23 15:44:22.513000
# age                                                         24
# zipcode                                                  78741
# term_bnb                   Small, quaint hotel with breakfast
# trav_per_year                                                2
# type_lodging                                             Hotel
# why_lodging        Not sketchy, rewards points, free breakfast
# who_travel                           With friends, With family
# num_people                                          3-4 people
# find_rec                                                     3
# find_social                                                  2
# find_google                                                  4
# find_online                                                  3
# app_website                                            Website
# matters_tours                                                6
# matters_food                                                 5
# matters_relax                                                3
# matters_shopping                                             2
# matters_meeting                                              2
# matters_immersing                                            5
# covid_travel                                               Yes
# covid_lodging                                   Hotel, Airbnb
# covid_issues         Less amenities, smaller breakfast options
#
#                                                                   8   \
# index                                                              8
# timestamp                                 2021-03-23 15:45:18.806000
# age                                                               23
# zipcode                                                        78751
# term_bnb                                                     A hotel
# trav_per_year                                                      2
# type_lodging                                                  AirBnb
# why_lodging                   It’s cheaper and there’s more options
# who_travel                                 With friends, With family
# num_people                                                1-2 people
# find_rec                                                           1
# find_social                                                        2
# find_google                                                        3
# find_online                                                        4
# app_website                                                  Website
# matters_tours                                                      1
# matters_food                                                       2
# matters_relax                                                      2
# matters_shopping                                                   2
# matters_meeting                                                    3
# matters_immersing                                                  6
# covid_travel                                                     Yes
# covid_lodging      Air bnb, they had good cleaning procedures tha...
# covid_issues       A lot of restaurants and places were closed in...
#
#                                                                   9   ...  \
# index                                                              9  ...
# timestamp                                 2021-03-23 15:45:42.216000  ...
# age                                                               27  ...
# zipcode                                                        11370  ...
# term_bnb                                                       Cabin  ...
# trav_per_year                                                      2  ...
# type_lodging                                                  AirBnb  ...
# why_lodging                                         Feels more homey  ...
# who_travel                                               With family  ...
# num_people                                                1-2 people  ...
# find_rec                                                           2  ...
# find_social                                                        2  ...
# find_google                                                        4  ...
# find_online                                                        4  ...
# app_website                                                      App  ...
# matters_tours                                                      4  ...
# matters_food                                                       5  ...
# matters_relax                                                      5  ...
# matters_shopping                                                   3  ...
# matters_meeting                                                    4  ...
# matters_immersing                                                  6  ...
# covid_travel                                                     Yes  ...
# covid_lodging      Friend's home, most accessible and least likel...  ...
# covid_issues                                                      No  ...
#
#                                                      22  \
# index                                                22
# timestamp                    2021-03-23 17:00:30.561000
# age                                                  18
# zipcode                                           60609
# term_bnb                                         travel
# trav_per_year                                         1
# type_lodging                                      Hotel
# why_lodging                       Safest, most credible
# who_travel         By myself, With friends, With family
# num_people                                   3-4 people
# find_rec                                              1
# find_social                                           1
# find_google                                           4
# find_online                                           2
# app_website                                     Website
# matters_tours                                         4
# matters_food                                          3
# matters_relax                                         5
# matters_shopping                                      1
# matters_meeting                                       3
# matters_immersing                                     6
# covid_travel                                         No
# covid_lodging                                       NaN
# covid_issues                                        NaN
#
#                                                                   23  \
# index                                                             23
# timestamp                                 2021-03-23 17:55:15.672000
# age                                                               24
# zipcode                                                        78705
# term_bnb           Place to stay overnight that is quaint and has...
# trav_per_year                                                      2
# type_lodging                                                   Hotel
# why_lodging        More availability and usually more cost effici...
# who_travel                                 With friends, With family
# num_people                                                3-4 people
# find_rec                                                           3
# find_social                                                        1
# find_google                                                        4
# find_online                                                        3
# app_website                                                  Website
# matters_tours                                                      4
# matters_food                                                       6
# matters_relax                                                      3
# matters_shopping                                                   5
# matters_meeting                                                    1
# matters_immersing                                                  2
# covid_travel                                                     Yes
# covid_lodging                    Resort - closer to day destination
# covid_issues                                                      No
#
#                                            24  \
# index                                      24
# timestamp          2021-03-23 18:28:27.486000
# age                                        23
# zipcode                                 77058
# term_bnb                             A hotel
# trav_per_year                               1
# type_lodging                          Family
# why_lodging                It is inexpensive
# who_travel                        With family
# num_people                         1-2 people
# find_rec                                    3
# find_social                                 3
# find_google                                 3
# find_online                                 1
# app_website                           Website
# matters_tours                               3
# matters_food                                3
# matters_relax                               3
# matters_shopping                            3
# matters_meeting                             2
# matters_immersing                           2
# covid_travel                               No
# covid_lodging                           None
# covid_issues                            None
#
#                                                                   25  \
# index                                                             25
# timestamp                                 2021-03-23 18:56:51.489000
# age                                                               20
# zipcode                                                        33428
# term_bnb           A hotel or inn that serves complimentary break...
# trav_per_year                                                      2
# type_lodging                                                  AirBnb
# why_lodging        It can be way cheeper for being able to have a...
# who_travel                                              With friends
# num_people                                                1-2 people
# find_rec                                                           2
# find_social                                                        1
# find_google                                                        3
# find_online                                                        4
# app_website                                                  Website
# matters_tours                                                      4
# matters_food                                                       5
# matters_relax                                                      2
# matters_shopping                                                   1
# matters_meeting                                                    3
# matters_immersing                                                  6
# covid_travel                                                     Yes
# covid_lodging      I’m going in April and tend to use AirBnb and ...
# covid_issues       When it comes to AirBnb the only concern was f...
#
#                                                                   26  \
# index                                                             26
# timestamp                                 2021-03-23 19:02:34.863000
# age                                                               24
# zipcode                                                        78628
# term_bnb           Romantic partners going on some sort of getawa...
# trav_per_year                                                      2
# type_lodging                                                  AirBnb
# why_lodging        It’s a pretty safe option, plus there’s usuall...
# who_travel                                              With friends
# num_people                                                3-4 people
# find_rec                                                           1
# find_social                                                        1
# find_google                                                        3
# find_online                                                        1
# app_website                                                  Website
# matters_tours                                                      1
# matters_food                                                       2
# matters_relax                                                      2
# matters_shopping                                                   1
# matters_meeting                                                    1
# matters_immersing                                                  3
# covid_travel                                                     Yes
# covid_lodging      I stayed at an air bnb a few times and then I ...
# covid_issues       I wasn’t worried about myself per say, I more ...
#
#                                                      27  \
# index                                                27
# timestamp                    2021-03-23 22:36:43.227000
# age                                                  41
# zipcode                                           11238
# term_bnb                                    Countryside
# trav_per_year                                         2
# type_lodging                        Hotel and local inn
# why_lodging                 Depends on the desitination
# who_travel         By myself, With friends, With family
# num_people                                   1-2 people
# find_rec                                              4
# find_social                                           2
# find_google                                           3
# find_online                                           4
# app_website                                     Website
# matters_tours                                         5
# matters_food                                          4
# matters_relax                                         3
# matters_shopping                                      1
# matters_meeting                                       5
# matters_immersing                                     6
# covid_travel                                         No
# covid_lodging                                       NaN
# covid_issues                                        NaN
#
#                                                        28  \
# index                                                  28
# timestamp                      2021-03-24 02:03:19.911000
# age                                                    25
# zipcode                                             75074
# term_bnb                                            Cute
# trav_per_year                                           3
# type_lodging                                        Hotel
# why_lodging                                   Facilities
# who_travel                                    With family
# num_people                                     3-4 people
# find_rec                                                4
# find_social                                             2
# find_google                                             4
# find_online                                             4
# app_website                                       Website
# matters_tours                                           6
# matters_food                                            6
# matters_relax                                           6
# matters_shopping                                        6
# matters_meeting                                         3
# matters_immersing                                       3
# covid_travel                                          Yes
# covid_lodging      Home of friends or family due to covid
# covid_issues                      Yes, exposure concerns
#
#                                                                   29  \
# index                                                             29
# timestamp                                 2021-03-24 13:17:50.078000
# age                                                               42
# zipcode                                                        11205
# term_bnb           Old Victorian house with lots of old people an...
# trav_per_year                                                      2
# type_lodging                                                  AirBnb
# why_lodging        Depends on where I am going.  I like to have a...
# who_travel                      By myself, With friends, With family
# num_people                                                1-2 people
# find_rec                                                           3
# find_social                                                        2
# find_google                                                        4
# find_online                                                        4
# app_website                                                      App
# matters_tours                                                      2
# matters_food                                                       6
# matters_relax                                                      6
# matters_shopping                                                   1
# matters_meeting                                                    3
# matters_immersing                                                  6
# covid_travel                                                      No
# covid_lodging                                                    NaN
# covid_issues                                                     NaN
#
#                                                                   30  \
# index                                                             30
# timestamp                                 2021-03-24 17:01:27.731000
# age                                                              NaN
# zipcode                                                          NaN
# term_bnb           basic room with basic breakfast in a dining ro...
# trav_per_year                                                      3
# type_lodging                                                   Hotel
# why_lodging            I prefer to have as many amenities available
# who_travel                                   By myself, With friends
# num_people                                                1-2 people
# find_rec                                                           1
# find_social                                                        1
# find_google                                                        4
# find_online                                                        4
# app_website                                                      App
# matters_tours                                                      1
# matters_food                                                       6
# matters_relax                                                      1
# matters_shopping                                                   4
# matters_meeting                                                    6
# matters_immersing                                                  6
# covid_travel                                                      No
# covid_lodging                                                    NaN
# covid_issues                                                     NaN
#
#                                                                   31
# index                                                             31
# timestamp                                 2021-03-24 17:05:00.884000
# age                                                               25
# zipcode                                                        94530
# term_bnb           small quaint hotel/motel that has food include...
# trav_per_year                                                      3
# type_lodging                                                  AirBnb
# why_lodging        I don't like being around a bunch of tourists ...
# who_travel                      With friends, With family, with S.O.
# num_people                                                1-2 people
# find_rec                                                           1
# find_social                                                        1
# find_google                                                        4
# find_online                                                        4
# app_website                                                      App
# matters_tours                                                      1
# matters_food                                                       6
# matters_relax                                                      6
# matters_shopping                                                   1
# matters_meeting                                                    1
# matters_immersing                                                  6
# covid_travel                                                     Yes
# covid_lodging      Airbnb or Motel - it's safer bc less interacti...
# covid_issues                                                    nope
#
# [24 rows x 32 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Functions

# %%
"""
  

"""

def prepare_table(data, column_range):
    dataframe = pd.DataFrame()
    number_of_columns = len(column_range)
    for each_column in column_range:
        new_tobe_row = round(data[each_column].value_counts(normalize = True) * 100 ,0)
        #print(new_tobe_row)
        dataframe = pd.concat([dataframe, new_tobe_row], axis =1 )
    return dataframe

# %% [markdown]
# # EDA
# <hr/>

# %% [markdown]
# ### Age

# %%
# plot of ages

df1['age'].hist();

# %% [markdown]
# # Zipcode

# %%
# number of zipcodes

df1['zipcode'].nunique()
# Out:
# 26

# %%
# list of zip codes

df1['zipcode'].unique()
# Out:
# array([10514., 60611., 60605.,  1605., 20024., 78741., 78751., 11370.,
#         1850., 75081., 90404., 77027.,  2176.,    nan, 77551., 77058.,
#         1906., 60067., 20707., 60609., 78705., 33428., 78628., 11238.,
#        75074., 11205., 94530.])

# %% [markdown]
# # How often do you usually travel per year?
# <hr/>

# %%
df1['trav_per_year'].value_counts(normalize = True)
# Out:
# 2    0.53125
# 1    0.25000
# 3    0.21875
# Name: trav_per_year, dtype: float64

# %% [markdown]
# # What type of lodging do you most often stay at?
# <hr/>

# %%
# in %

df1['type_lodging'].value_counts(normalize = True) * 100
# Out:
# Hotel                           50.000
# AirBnb                          34.375
# Family                           6.250
# Hotel and local inn              3.125
# Split between Hotels and Air     3.125
# Whatever is cheapest             3.125
# Name: type_lodging, dtype: float64

# %% [markdown]
# # Who do you usually travel with?
# <hr>

# %%
df1['who_travel'].value_counts()
# Out:
# With friends, With family                          8
# With family                                        8
# With friends                                       4
# By myself                                          3
# By myself, With friends, With family               3
# By myself, With family                             2
# With friends, With family, with S.O.               1
# with partner                                       1
# By myself, With friends, With family, With kids    1
# By myself, With friends                            1
# Name: who_travel, dtype: int64

# %% [markdown]
# # How many people do you travel with?
# <hr/>

# %%
df1['num_people'].value_counts()
# Out:
# 1-2 people    18
# 3-4 people    12
# 5+ people      1
# None           1
# Name: num_people, dtype: int64

# %% [markdown]
# # Do you prefer to use an app or website when booking your travel accommodations?
# <hr/>

# %%
# in %

df1['app_website'].value_counts(normalize = True)*100
# Out:
# Website    78.125
# App        21.875
# Name: app_website, dtype: float64

# %% [markdown]
# # Have you travelled during the pandemic?
# <hr>

# %%
# in %

df1['covid_travel'].value_counts(normalize = True)* 100
# Out:
# Yes    59.375
# No     40.625
# Name: covid_travel, dtype: float64

# %% [markdown]
# # If YES,  what type of lodging did you stay at and why?
# <hr/>

# %%
df1['covid_lodging']
# Out:
# 0                                   Hotel for ease/safe
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5     Hotel.  Normally would've stayed with family, ...
# 6                                                   NaN
# 7                                        Hotel, Airbnb
# 8     Air bnb, they had good cleaning procedures tha...
# 9     Friend's home, most accessible and least likel...
# 10    AirBnB cabin with a hot tub. We wanted to get ...
# 11                           Stayed at a friends house.
# 12                           Condo rental /rental home
# 13    Air bnb, easier to find for more remote locati...
# 14    Campgrounds, Airs, Hotels - As many campground...
# 15                                                  NaN
# 16                                        Family House
# 17                                                None
# 18                                                  NaN
# 19    Friends' house. Also had friends that stayed a...
# 20    Air bnb, easier to find for more remote locati...
# 21                                     Family Residence
# 22                                                  NaN
# 23                  Resort - closer to day destination
# 24                                                None
# 25    I’m going in April and tend to use AirBnb and ...
# 26    I stayed at an air bnb a few times and then I ...
# 27                                                  NaN
# 28               Home of friends or family due to covid
# 29                                                  NaN
# 30                                                  NaN
# 31    Airbnb or Motel - it's safer bc less interacti...
# Name: covid_lodging, dtype: object

# %% [markdown]
# # If YES,  did you have any concerns or difficulties during your stay in relation to COVID?
# <hr/>

# %%
df1['covid_issues']
# Out:
# 0                                                    No
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5     Yes, staffing levels were reduced, which resul...
# 6                                                   NaN
# 7             Less amenities, smaller breakfast options
# 8     A lot of restaurants and places were closed in...
# 9                                                    No
# 10                                                   No
# 11    I travelled through multiple states and it was...
# 12                           Pool usage at rented condo
# 13    When new travel restrictions were implemented ...
# 14    No. Places were were empty and just like anywh...
# 15                                                  NaN
# 16                         Some just social distancing
# 17                                                None
# 18                                                  NaN
# 19    No real concerns with COVID. Travelled followi...
# 20    When new travel restrictions were implemented ...
# 21                                            No issues
# 22                                                  NaN
# 23                                                   No
# 24                                                None
# 25    When it comes to AirBnb the only concern was f...
# 26    I wasn’t worried about myself per say, I more ...
# 27                                                  NaN
# 28                              Yes, exposure concerns
# 29                                                  NaN
# 30                                                  NaN
# 31                                                 nope
# Name: covid_issues, dtype: object

# %% [markdown]
# # Why do you typically choose that lodging option?
# <hr/>

# %%
df1['why_lodging']
# Out:
# 0                       Experience. Know what to expect
# 1                     Free parking, breakfast included
# 2     Easiest option to book without research, can u...
# 3     location, proximity to places of interest, ame...
# 4                                          Convenience
# 5                           Consistent quality/features
# 6     Big hotel chains are easy to find and expense ...
# 7           Not sketchy, rewards points, free breakfast
# 8                It’s cheaper and there’s more options
# 9                                      Feels more homey
# 10           It's cheaper and offers more than a hotel.
# 11                      Room rates and rewards program.
# 12    I can find  exactly (or close) to what I want ...
# 13    Easy to book, lots of options, usually closest...
# 14    Hotel: Shorter trip --- Air: Longer trip or mo...
# 15                    I try not to spend too much money
# 16    More personal and more involved in wherever I am!
# 17                                   It is inexpensive
# 18    Convenience and accessibility. Airbnb offers m...
# 19                  Easy to access and feels more homey
# 20    Easy to book, lots of options, usually closest...
# 21                      Room amenities and style, price
# 22                                Safest, most credible
# 23    More availability and usually more cost effici...
# 24                                   It is inexpensive
# 25    It can be way cheeper for being able to have a...
# 26    It’s a pretty safe option, plus there’s usuall...
# 27                          Depends on the desitination
# 28                                          Facilities
# 29    Depends on where I am going.  I like to have a...
# 30        I prefer to have as many amenities available
# 31    I don't like being around a bunch of tourists ...
# Name: why_lodging, dtype: object

# %% [markdown]
# # "Bed and Breakfast", what comes to mind
# <hr/>

# %%
df1['term_bnb'].unique()
# Out:
# array(['Charming vacation ', 'Tea and bread',
#        'Motel, AirBnb, cozy lodging in countryside',
#        'inexpensive lodging, comfort of home away from home', 'Homey',
#        'Quaint vacation lodging', 'Small family-owned vacation home',
#        'Small, quaint hotel with breakfast ', 'A hotel', 'Cabin',
#        'AirBnB',
#        'Overnight accommodations which includes breakfast the next morning.',
#        'Cute little place, family friendly, couples, good breakfast, hospitality ',
#        'Relaxing amenities, cooked meals, quiet getaway',
#        'Everything AirBnB - Also corny country inns - Couples weekends',
#        'A small inn, locally owned. Definitely not a large chain like Hampton. ',
#        'A hotel ',
#        'Comfortable lodging with food and amenities. Low cost for nightly stays. ',
#        'Vermont and fall',
#        'Traditional, colonial style housing, affordable, low-end amenities focus on lodging',
#        'travel',
#        'Place to stay overnight that is quaint and has breakfast provided.',
#        'A hotel or inn that serves complimentary breakfast.',
#        'Romantic partners going on some sort of getaway and staying in a little house that serves you food',
#        'Countryside', 'Cute ',
#        'Old Victorian house with lots of old people and free scones in the morning.  ',
#        'basic room with basic breakfast in a dining room - not breakfast in bed',
#        'small quaint hotel/motel that has food included in the price'],
#       dtype=object)

# %%
# lemitize

# %%
# word count

# %%
# Emotinal inflextion

# %%
####

# %%
df1['find_rec'].value_counts()
# Out:
# 3    9
# 2    9
# 1    9
# 4    5
# Name: find_rec, dtype: int64

# %%
places_df = df1[['find_rec','find_social','find_google','find_online']]
places_df.reset_index()
# Out:
#     index  find_rec  find_social  find_google  find_online
# 0       0         1            2            3            4
# 1       1         2            1            4            4
# 2       2         3            4            2            1
# 3       3         2            2            4            1
# 4       4         2            3            4            4
# 5       5         2            1            3            4
# 6       6         2            1            4            3
# 7       7         3            2            4            3
# 8       8         1            2            3            4
# 9       9         2            2            4            4
# 10     10         3            1            3            4
# 11     11         3            1            4            2
# 12     12         3            1            2            4
# 13     13         1            2            4            3
# 14     14         2            2            2            2
# 15     15         1            1            3            4
# 16     16         4            2            2            4
# 17     17         3            3            3            1
# 18     18         2            2            4            4
# 19     19         4            4            4            4
# 20     20         1            2            4            3
# 21     21         4            1            4            3
# 22     22         1            1            4            2
# 23     23         3            1            4            3
# 24     24         3            3            3            1
# 25     25         2            1            3            4
# 26     26         1            1            3            1
# 27     27         4            2            3            4
# 28     28         4            2            4            4
# 29     29         3            2            4            4
# 30     30         1            1            4            4
# 31     31         1            1            4            4

# %%
from collections import Counter

# %%
Counter(df1['find_rec']).values()
# Out:
# dict_values([9, 9, 9, 5])

# %%
Counter(df1['find_rec']).keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
Counter(df1['find_rec']).items()
# Out:
# dict_items([(1, 9), (2, 9), (3, 9), (4, 5)])

# %%
df = pd.DataFrame()

# %% [markdown]
# ### Create DF for
# <hr/>
# How do you typically find places to stay at while traveling?

# %%
df1['find_online'].value_counts(normalize = True) * 100
# Out:
# 4    56.250
# 3    18.750
# 1    15.625
# 2     9.375
# Name: find_online, dtype: float64

# %% [markdown]
# How do you typically find places to stay at while traveling? Please rank from 1-4, with 4 being the method you rely on most. [Recommendations from friends/family] 	1

# %%
prepare_table(df1, ['find_rec','find_social','find_google','find_online'])
# Out:
#    find_rec  find_social  find_google  find_online
# 1      28.0         44.0          NaN         16.0
# 2      28.0         41.0         12.0          9.0
# 3      28.0          9.0         31.0         19.0
# 4      16.0          6.0         56.0         56.0

# %%
When you book a vacation, what matters to you? Please rank from 1-6, with 6 being most important. [Food/Restaurants/Bars] 	4

# %%
prepare_table(df1, ['matters_tours','matters_food','matters_relax',
                    'matters_shopping','matters_meeting', 'matters_immersing']).T
# Out:
#                       1     2     3     4     5     6
# matters_tours      22.0  12.0  12.0  19.0   6.0  28.0
# matters_food        NaN   6.0  19.0  22.0  19.0  34.0
# matters_relax       3.0  12.0  22.0  12.0  25.0  25.0
# matters_shopping   31.0  31.0  16.0   6.0   9.0   6.0
# matters_meeting    34.0  28.0  16.0   6.0   6.0   9.0
# matters_immersing   3.0   9.0   9.0   9.0  19.0  50.0

# %%
x.iloc[:,0]
# Out:
# 1    7
# 2    4
# 3    4
# 4    6
# 5    2
# 6    9
# Name: matters_tours, dtype: int64

# %% [markdown]
# <br>

# %%
df1.to_csv('../clean_data/questionare.csv')

# %%
df1['matters_tours'].mean()
# Out:
# 3.59375

# %%
df1['matters_food'].mean()
# Out:
# 4.5625

# %%
df1['matters_relax'].mean()
# Out:
# 4.1875

# %%
df1['matters_shopping'].mean()
# Out:
# 2.5

# %%
df1['matters_meeting'].mean()
# Out:
# 2.5

# %%
df1['matter_immersing'].mean()
# Out:
# 4.8125

# %%
(a + b + c + d + e + f) / f
# Out:
# 4.603896103896104

# %%
df1['term_bnb']
# Out:
# 0                                    Charming vacation
# 1                                         Tea and bread
# 2            Motel, AirBnb, cozy lodging in countryside
# 3     inexpensive lodging, comfort of home away from...
# 4                                                 Homey
# 5                               Quaint vacation lodging
# 6                      Small family-owned vacation home
# 7                   Small, quaint hotel with breakfast
# 8                                               A hotel
# 9                                                 Cabin
# 10                                               AirBnB
# 11    Overnight accommodations which includes breakf...
# 12    Cute little place, family friendly, couples, g...
# 13      Relaxing amenities, cooked meals, quiet getaway
# 14    Everything AirBnB - Also corny country inns - ...
# 15    A small inn, locally owned. Definitely not a l...
# 16                                               AirBnB
# 17                                             A hotel
# 18    Comfortable lodging with food and amenities. L...
# 19                                     Vermont and fall
# 20      Relaxing amenities, cooked meals, quiet getaway
# 21    Traditional, colonial style housing, affordabl...
# 22                                               travel
# 23    Place to stay overnight that is quaint and has...
# 24                                             A hotel
# 25    A hotel or inn that serves complimentary break...
# 26    Romantic partners going on some sort of getawa...
# 27                                          Countryside
# 28                                                Cute
# 29    Old Victorian house with lots of old people an...
# 30    basic room with basic breakfast in a dining ro...
# 31    small quaint hotel/motel that has food include...
# Name: term_bnb, dtype: object

# %%
df1['type_lodging'].value_counts(normalize=True)
# Out:
# Hotel                           0.50000
# AirBnb                          0.34375
# Family                          0.06250
# Whatever is cheapest            0.03125
# Hotel and local inn             0.03125
# Split between Hotels and Air    0.03125
# Name: type_lodging, dtype: float64

# %%
sns.histplot(data = df1,x ='type_lodging' pallet = )
