# %%
import pandas as pd

# %%
df = pd.read_excel('../data/Post-pandemic_travel_lodging-1.xlsx' )
# print(df1.shape)
# df1.head()

# %%
df.T
# Out:
#                                                                                   0  \
# Timestamp                                                2021-03-23 15:38:11.493000
# What is your age?                                                                34
# What is your home zip code?                                                   10514
# When you hear the term "bed and breakfast", wha...               Charming vacation
# How often do you usually travel?                                                  2
# What type of lodging do you most often stay at ...                            Hotel
# Why do you typically choose that lodging option?    Experience. Know what to expect
# Who do you usually travel with?                                         With family
# How many people do you travel with?                                      3-4 people
# How do you typically find places to stay at whi...                                1
# ...
